# %% [markdown]
# STUDENT TODO: Fill-In Documentation Header with Markdown

# %% [markdown]
# # Documentation Header
# - **Author:** Kody Knight
# - **Major:** Computer science
# - **Creation Date:** 4/22/2022 12:50
# - **Due Date:** 4/22/2022
# - **Course:** CSC 223
# - **Professor Name:** Patrick earl
# - **Assignment NUmber:** 5
# - **Filename:** Main.ipynb
# - **purpose:** to demonstraite the ability to use matplotlib by graphing data from ratings and making a bar chat for for top 10 movies by votes

# %%
# %matplotlib inline

# STUDENT TODO: Write statements to import numpy, pandas, & matplotlib.pyplot
# following conventions. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# STUDENT: Do not modify the code in this cell. 

def norm_dist(x, mean, std):
    '''
        Use this function to calculate a normal distribution
        
        Parameters:
            x - 1D Array of Distribution
            mean - The mean of the dataset
            std - The standard deviation of the dataset
            
        Return:
            A numpy array
    '''
    from scipy.stats import norm
    return norm.pdf(x, mean, std)
    

# Import the dataset
movies = pd.read_csv('https://faculty.kutztown.edu/earl/teaching/2021-2022/223-adv-sci-program/hw/materials/movies.csv', index_col=0)
movies.head()
# Out:
#                       title  year  length  budget  rating  votes    r1    r2  \
# 1                         $  1971     121     NaN     6.4    348   4.5   4.5
# 2         $1000 a Touchdown  1939      71     NaN     6.0     20   0.0  14.5
# 3    $21 a Day Once a Month  1941       7     NaN     8.2      5   0.0   0.0
# 4                   $40,000  1996      70     NaN     8.2      6  14.5   0.0
# 5  $50,000 Climax Show, The  1975      71     NaN     3.4     17  24.5   4.5
#
#     r3    r4  ...    r9   r10  mpaa  Action  Animation  Comedy Drama  \
# 1  4.5   4.5  ...   4.5   4.5   NaN       0          0       1     1
# 2  4.5  24.5  ...   4.5  14.5   NaN       0          0       1     0
# 3  0.0   0.0  ...  24.5  24.5   NaN       0          1       0     0
# 4  0.0   0.0  ...  34.5  45.5   NaN       0          0       1     0
# 5  0.0  14.5  ...   0.0  24.5   NaN       0          0       0     0
#
#    Documentary  Romance  Short
# 1            0        0      0
# ...

# %%
# STUDENT TODO: Code for Figure 1
ratings = movies['rating'].sort_values()
plt.hist(ratings,bins = 10, density = True)
plt.title("Amount of Ratings vs. Rating")
plt.xlabel("Rating")
plt.ylabel("Amount of Ratings")
plt.subplot()
plt.plot(ratings,norm_dist(ratings,ratings.mean(),ratings.std()))
plt.legend(['Ratings Average','Ratings'])
plt.show()

# %%
# STUDENT TODO: Code for Figure 2
movies = movies.set_index('votes')
movies = movies.sort_index(ascending = False)
movies = movies.head(10)
Titles = movies['title']
fig, ax = plt.subplots()
ax.barh(Titles,movies.index)
plt.title("Top 10 movies")
plt.ylabel("Movies")
plt.xlabel("Votes")
plt.show()
